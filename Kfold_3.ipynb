# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

train = pd.read_csv('playground-series-s5e5/train.csv')
test = pd.read_csv('playground-series-s5e5/test.csv')

# %%
numerical_features = ["Age","Height","Weight","Duration","Heart_Rate","Body_Temp"]

# %%
import numpy as np 
import pandas as pd
import itertools 
from sklearn.preprocessing import LabelEncoder,PolynomialFeatures,StandardScaler
#積の列を作る
def add_feature_cross_terms(df,features):
    df = df.copy()
    df = df.loc[:,~df.columns.duplicated()]#df.columns.duplicated()で重複したのをtrue/falseで判定し~でビット反転でfalseのみ残る
    for i in range(len(features)):
        for j in range(i+1,len(features)):
            f1 = features[i]
            f2 = features[j]
            df[f"{f1}_x_{f2}"] = df[f1]*df[f1]
    return df
#和、差、商の列を作る
def add_intersection_features(df,features):
    df_new = df.copy()
    for f1,f2 in itertools.combinations(features,2):
        df_new[f"{f1}_plus_{f2}"] = df_new[f1]+df_new[f2]
        df_new[f"{f1}_minus_{f2}"] = df_new[f1]-df_new[f2]
        df_new[f"{f2}_minus_{f1}"] = df_new[f2]-df_new[f1]
        df_new[f"{f1}_div_{f2}"] = df_new[f1]/df_new[f2]
        df_new[f"{f2}_div_{f1}"] = df_new[f2]/df_new[f1]
    return df_new
#平均、標準偏差、最大値、最小値、中央値の列を作る
def add_statistical_features(df,features):
    df_new = df.copy()
    df_new["row_mean"] = df[features].mean(axis=1)
    df_new["row_std"] = df[features].std(axis=1)
    df_new["row_max"] = df[features].max(axis=1)
    df_new["row_min"] = df[features].min(axis=1)
    df_new["row_median"]  = df[features].median(axis=1)
    return df_new
#変換
train = add_feature_cross_terms(train,numerical_features)
test = add_feature_cross_terms(test,numerical_features)

train = add_intersection_features(train,numerical_features)
test = add_intersection_features(test,numerical_features)

train = add_statistical_features(train,numerical_features)
test = add_statistical_features(test,numerical_features)
#カテゴリデータをラベルエンコーダで変換
le = LabelEncoder()
train["Sex"] = le.fit_transform(train["Sex"])
test["Sex"] = le.transform(test["Sex"])
#モデルがカテゴリーと分かるようにする
train["Sex"] = train["Sex"].astype("category")
test["Sex"] = test["Sex"].astype("category")

#多項式で表現できるようにする
poly = PolynomialFeatures(degree=2,interaction_only = True,include_bias=False)
poly_train = poly.fit_transform(train[numerical_features])
poly_test = poly.transform(test[numerical_features])
poly_feature_names = poly.get_feature_names_out(numerical_features)

#データフレームに変換
poly_train_df = pd.DataFrame(poly_train,columns=poly_feature_names)
poly_test_df = pd.DataFrame(poly_test,columns=poly_feature_names)

#横方向（列方向）にくっつけてる
train = pd.concat([train.reset_index(drop=True),poly_train_df],axis=1)
test = pd.concat([test.reset_index(drop=True),poly_test_df],axis=1)

#X,yを作ってyはスケールを変えておく
X = train.drop(columns=['id','Calories'])
y = np.log1p(train['Calories'])
X_test = test.drop(columns=['id'])

FEATURES = X.columns.tolist()

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in /opt/anaconda3/lib/python3.11/site-packages (1.2.8)
# Requirement already satisfied: graphviz in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from plotly->catboost) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import time

FOLDS = 4
kf = KFold(n_splits=FOLDS,shuffle=True,random_state=42)
models = {
    'CatBoostRegressor':CatBoostRegressor(
        verbose=1,#ログ
        random_state=42,
        cat_features=['Sex'],#カテゴリカル変数の指定
        early_stopping_rounds=20#検証スコアがX回連続で変化しなかったら停止
        ),
    'XGBoost':XGBRegressor(
        max_depth=10,#決定木の深さ
        col_sample_bytree=.7,#各決定木を作る時の特徴量の割合
        subsample=.9,#各木を作成する際に使用するサンプル数の割合
        n_estimators=500,#作る木の本数
        learning_rate=.02,#各ステップの学習率
        gamma=.01,#ノード分割のために必要な損失関数の最小減少量
        max_delta_step=2,#一回の重み更新で変化できる最大ステップ量
        early_stopping_rounds=50,
        eval_metric='rmse',#モデルの性能を評価する指標
        enable_categorical=True,#カテゴリ変数を直接扱えるようにする
        random_state=42
    ),
    'LightGBM':LGBMRegressor(
        n_estimators=500,#作る木の本数
        learning_rate=.02,#各ステップの学習率
        max_depth=10,#決定木の深さ
        colsample_bytree=.7,#各決定木を作る時の特徴量の割合
        subsample=.9,#各木を作成する際に使用するサンプル数の割合
        random_state=42,
        verbose=-1#ログを一切出さない
    )
}

# %%
#モデルごとに初期化
results = {
    name:{
        'oof':np.zeros(len(train)),#Out Of Fold予測値（訓練データ用）
        'pred':np.zeros(len(test)),#テストデータへの予測の平均
        'rmsle':[]#各FoldのRMSLEを格納
        } 
        for name in models}

#モデルごとにKFold学習を実行
for name,model in models.items():
    print(f"\n=== Training {name} ===")

    for i,(train_idx,valid_idx) in enumerate(kf.split(X,y)):
        print(f"\nFold {i+1}")
        
        #学習用データと検証用データに分割
        x_train,y_train = X.iloc[train_idx],y[train_idx]
        x_valid,y_valid = X.iloc[valid_idx],y[valid_idx]

        #重複カラムを除去
        x_train = x_train.loc[:,~x_train.columns.duplicated()]
        x_valid = x_valid.loc[:,~x_valid.columns.duplicated()]
        x_test = X_test.loc[:,~X_test.columns.duplicated()].copy()

        start = time.time()

        #モデルに応じたfit方法を選択
        if name == 'XGBoost':
            model.fit(x_train,y_train,eval_set=[(x_valid,y_valid)],verbose=1)
        elif name == 'CatBoost':#CatBoostはタプルで渡す
            model.fit(x_train,y_train,eval_set=(x_valid,y_valid))
        else:
            model.fit(x_train,y_train)
        
        #検証用データとテストデータの予測
        oof_pred = model.predict(x_valid)
        test_pred = model.predict(x_test)

        #oof予測を該当インデックスに保存
        results[name]['oof'][valid_idx] =oof_pred

        #テスト予測はFOLD数で割って平均（アンサンブル用）
        results[name]['pred'] += test_pred/FOLDS

        #RMSLE計算(log誤差)を格納
        rmsle = np.sqrt(mean_squared_log_error(np.expm1(y_valid),np.expm1(oof_pred)))
        results[name]['rmsle'].append(rmsle)

        #各Foldのログ出力
        print(f"Fold {i+1} RMSLE: {rmsle:.4f}")
        print(f"Training time: {time.time()-start:.1f} sec")

#モデルごとのRMSLE平均・標準偏差を出力
print("\n=== Model Comparison ===")
for name in models:
    mean_rmsle = np.mean(results[name]['rmsle'])
    std_rmsle = np.std(results[name]['rmsle'])
    print(f"{name} - Mean RMSLE: {mean_rmsle:.4f} ± {std_rmsle:.4f}")
# Out:
# === Training CatBoostRegressor ===
#
# Fold 1
# Learning rate set to 0.111352
# 613:	learn: 0.0572617	total: 19.3s	remaining: 12.1s
# 614:	learn: 0.0572559	total: 19.3s	remaining: 12.1s
# 615:	learn: 0.0572512	total: 19.3s	remaining: 12s
# 616:	learn: 0.0572488	total: 19.3s	remaining: 12s
# 617:	learn: 0.0572452	total: 19.4s	remaining: 12s
# 618:	learn: 0.0572365	total: 19.4s	remaining: 11.9s
# 619:	learn: 0.0572306	total: 19.4s	remaining: 11.9s
# 620:	learn: 0.0572270	total: 19.5s	remaining: 11.9s
# 621:	learn: 0.0572235	total: 19.5s	remaining: 11.8s
# 622:	learn: 0.0572207	total: 19.5s	remaining: 11.8s
# 623:	learn: 0.0572154	total: 19.5s	remaining: 11.8s
# 624:	learn: 0.0572098	total: 19.6s	remaining: 11.8s
# 625:	learn: 0.0572050	total: 19.6s	remaining: 11.7s
# 626:	learn: 0.0571999	total: 19.7s	remaining: 11.7s
# 627:	learn: 0.0571945	total: 19.7s	remaining: 11.7s
# 628:	learn: 0.0571885	total: 19.7s	remaining: 11.6s
# 629:	learn: 0.0571849	total: 19.7s	remaining: 11.6s
# 630:	learn: 0.0571808	total: 19.8s	remaining: 11.6s
# 631:	learn: 0.0571746	total: 19.8s	remaining: 11.5s
# 632:	learn: 0.0571716	total: 19.9s	remaining: 11.5s
# 633:	learn: 0.0571662	total: 19.9s	remaining: 11.5s
# 634:	learn: 0.0571638	total: 19.9s	remaining: 11.5s
# 635:	learn: 0.0571583	total: 20s	remaining: 11.4s
# 636:	learn: 0.0571543	total: 20s	remaining: 11.4s
# 637:	learn: 0.0571519	total: 20s	remaining: 11.4s
# 638:	learn: 0.0571498	total: 20s	remaining: 11.3s
# 639:	learn: 0.0571434	total: 20.1s	remaining: 11.3s
# 640:	learn: 0.0571370	total: 20.1s	remaining: 11.3s
# 641:	learn: 0.0571331	total: 20.1s	remaining: 11.2s
# 642:	learn: 0.0571303	total: 20.2s	remaining: 11.2s
# 643:	learn: 0.0571267	total: 20.2s	remaining: 11.2s
# 644:	learn: 0.0571226	total: 20.2s	remaining: 11.1s
# 645:	learn: 0.0571182	total: 20.3s	remaining: 11.1s
# 646:	learn: 0.0571149	total: 20.3s	remaining: 11.1s
# 647:	learn: 0.0571085	total: 20.4s	remaining: 11.1s
# 648:	learn: 0.0571053	total: 20.4s	remaining: 11s
# 649:	learn: 0.0570993	total: 20.4s	remaining: 11s
# 650:	learn: 0.0570946	total: 20.4s	remaining: 11s
# 651:	learn: 0.0570905	total: 20.5s	remaining: 10.9s
# 652:	learn: 0.0570855	total: 20.5s	remaining: 10.9s
# 653:	learn: 0.0570799	total: 20.5s	remaining: 10.9s
# 654:	learn: 0.0570733	total: 20.6s	remaining: 10.8s
# 655:	learn: 0.0570681	total: 20.6s	remaining: 10.8s
# 656:	learn: 0.0570637	total: 20.6s	remaining: 10.8s
# 657:	learn: 0.0570618	total: 20.6s	remaining: 10.7s
# 658:	learn: 0.0570578	total: 20.7s	remaining: 10.7s
# 659:	learn: 0.0570527	total: 20.7s	remaining: 10.7s
# 802:	learn: 0.0564927	total: 25.1s	remaining: 6.16s
# 803:	learn: 0.0564892	total: 25.1s	remaining: 6.13s
# 804:	learn: 0.0564848	total: 25.2s	remaining: 6.1s
# 805:	learn: 0.0564811	total: 25.2s	remaining: 6.07s
# 806:	learn: 0.0564751	total: 25.2s	remaining: 6.04s
# 807:	learn: 0.0564734	total: 25.3s	remaining: 6s
# 808:	learn: 0.0564692	total: 25.3s	remaining: 5.97s
# 809:	learn: 0.0564671	total: 25.3s	remaining: 5.94s
# 810:	learn: 0.0564620	total: 25.4s	remaining: 5.91s
# 811:	learn: 0.0564579	total: 25.4s	remaining: 5.88s
# 812:	learn: 0.0564538	total: 25.4s	remaining: 5.85s
# 813:	learn: 0.0564496	total: 25.4s	remaining: 5.81s
# 814:	learn: 0.0564442	total: 25.5s	remaining: 5.78s
# 815:	learn: 0.0564407	total: 25.5s	remaining: 5.75s
# 816:	learn: 0.0564368	total: 25.5s	remaining: 5.72s
# 817:	learn: 0.0564324	total: 25.6s	remaining: 5.69s
# 818:	learn: 0.0564291	total: 25.6s	remaining: 5.66s
# 819:	learn: 0.0564246	total: 25.6s	remaining: 5.63s
# 820:	learn: 0.0564228	total: 25.7s	remaining: 5.6s
# 821:	learn: 0.0564196	total: 25.7s	remaining: 5.56s
# 822:	learn: 0.0564140	total: 25.7s	remaining: 5.53s
# 823:	learn: 0.0564107	total: 25.8s	remaining: 5.5s
# 824:	learn: 0.0564081	total: 25.8s	remaining: 5.47s
# 825:	learn: 0.0564046	total: 25.8s	remaining: 5.44s
# 826:	learn: 0.0564030	total: 25.8s	remaining: 5.41s
# 827:	learn: 0.0563978	total: 25.9s	remaining: 5.38s
# 828:	learn: 0.0563939	total: 25.9s	remaining: 5.34s
# 829:	learn: 0.0563876	total: 25.9s	remaining: 5.31s
# 830:	learn: 0.0563828	total: 26s	remaining: 5.28s
# 831:	learn: 0.0563784	total: 26s	remaining: 5.25s
# 832:	learn: 0.0563747	total: 26s	remaining: 5.22s
# 833:	learn: 0.0563707	total: 26.1s	remaining: 5.19s
# 834:	learn: 0.0563648	total: 26.1s	remaining: 5.16s
# 835:	learn: 0.0563608	total: 26.1s	remaining: 5.12s
# 836:	learn: 0.0563581	total: 26.2s	remaining: 5.09s
# 837:	learn: 0.0563561	total: 26.2s	remaining: 5.06s
# 838:	learn: 0.0563483	total: 26.2s	remaining: 5.03s
# 839:	learn: 0.0563460	total: 26.2s	remaining: 5s
# 840:	learn: 0.0563429	total: 26.3s	remaining: 4.97s
# 841:	learn: 0.0563385	total: 26.3s	remaining: 4.93s
# 842:	learn: 0.0563326	total: 26.3s	remaining: 4.9s
# 843:	learn: 0.0563278	total: 26.4s	remaining: 4.87s
# 844:	learn: 0.0563230	total: 26.4s	remaining: 4.84s
# 845:	learn: 0.0563197	total: 26.4s	remaining: 4.81s
# 846:	learn: 0.0563177	total: 26.4s	remaining: 4.78s
# 847:	learn: 0.0563136	total: 26.5s	remaining: 4.74s
# 895:	learn: 0.0561413	total: 27.9s	remaining: 3.24s
# 896:	learn: 0.0561376	total: 28s	remaining: 3.21s
# 897:	learn: 0.0561340	total: 28s	remaining: 3.18s
# 898:	learn: 0.0561312	total: 28s	remaining: 3.15s
# 899:	learn: 0.0561291	total: 28s	remaining: 3.12s
# 900:	learn: 0.0561246	total: 28.1s	remaining: 3.08s
# 901:	learn: 0.0561206	total: 28.1s	remaining: 3.05s
# 902:	learn: 0.0561186	total: 28.1s	remaining: 3.02s
# 903:	learn: 0.0561135	total: 28.2s	remaining: 2.99s
# 904:	learn: 0.0561093	total: 28.2s	remaining: 2.96s
# 905:	learn: 0.0561070	total: 28.2s	remaining: 2.93s
# 906:	learn: 0.0561045	total: 28.3s	remaining: 2.9s
# 907:	learn: 0.0561014	total: 28.3s	remaining: 2.87s
# 908:	learn: 0.0560989	total: 28.3s	remaining: 2.83s
# 909:	learn: 0.0560961	total: 28.4s	remaining: 2.8s
# 910:	learn: 0.0560931	total: 28.4s	remaining: 2.77s
# 911:	learn: 0.0560858	total: 28.4s	remaining: 2.74s
# 912:	learn: 0.0560822	total: 28.5s	remaining: 2.71s
# 913:	learn: 0.0560786	total: 28.5s	remaining: 2.68s
# 914:	learn: 0.0560756	total: 28.5s	remaining: 2.65s
# 915:	learn: 0.0560732	total: 28.6s	remaining: 2.62s
# 916:	learn: 0.0560704	total: 28.6s	remaining: 2.59s
# 917:	learn: 0.0560674	total: 28.6s	remaining: 2.56s
# 918:	learn: 0.0560649	total: 28.7s	remaining: 2.53s
# 919:	learn: 0.0560625	total: 28.7s	remaining: 2.5s
# 920:	learn: 0.0560583	total: 28.7s	remaining: 2.46s
# 921:	learn: 0.0560539	total: 28.8s	remaining: 2.43s
# 922:	learn: 0.0560530	total: 28.8s	remaining: 2.4s
# 923:	learn: 0.0560504	total: 28.8s	remaining: 2.37s
# 924:	learn: 0.0560458	total: 28.8s	remaining: 2.34s
# 925:	learn: 0.0560423	total: 28.9s	remaining: 2.31s
# 926:	learn: 0.0560374	total: 28.9s	remaining: 2.28s
# 927:	learn: 0.0560359	total: 28.9s	remaining: 2.25s
# 928:	learn: 0.0560341	total: 29s	remaining: 2.21s
# 929:	learn: 0.0560314	total: 29s	remaining: 2.18s
# ...
# [380]	validation_0-rmse:0.05987
# [381]	validation_0-rmse:0.05987
# [382]	validation_0-rmse:0.05987
# [383]	validation_0-rmse:0.05987
# [384]	validation_0-rmse:0.05987
# [385]	validation_0-rmse:0.05987
# [386]	validation_0-rmse:0.05987
# [387]	validation_0-rmse:0.05987
# [388]	validation_0-rmse:0.05987
# [389]	validation_0-rmse:0.05987
# [390]	validation_0-rmse:0.05987
# [391]	validation_0-rmse:0.05987
# [392]	validation_0-rmse:0.05987
# [393]	validation_0-rmse:0.05987
# [394]	validation_0-rmse:0.05987
# [395]	validation_0-rmse:0.05987
# [396]	validation_0-rmse:0.05987
# [397]	validation_0-rmse:0.05987
# [398]	validation_0-rmse:0.05987
# [399]	validation_0-rmse:0.05987
# [400]	validation_0-rmse:0.05987
# [401]	validation_0-rmse:0.05987
# [402]	validation_0-rmse:0.05987
# [403]	validation_0-rmse:0.05987
# [404]	validation_0-rmse:0.05987
# [405]	validation_0-rmse:0.05987
# [406]	validation_0-rmse:0.05987
# [407]	validation_0-rmse:0.05987
# [408]	validation_0-rmse:0.05987
# [409]	validation_0-rmse:0.05987
# [410]	validation_0-rmse:0.05987
# [411]	validation_0-rmse:0.05987
# [412]	validation_0-rmse:0.05987
# [413]	validation_0-rmse:0.05988
# [414]	validation_0-rmse:0.05987
# [415]	validation_0-rmse:0.05988
# [416]	validation_0-rmse:0.05988
# [417]	validation_0-rmse:0.05988
# [418]	validation_0-rmse:0.05988
# [419]	validation_0-rmse:0.05988
# [420]	validation_0-rmse:0.05988
# [421]	validation_0-rmse:0.05988
# [422]	validation_0-rmse:0.05988
# [423]	validation_0-rmse:0.05988
# [424]	validation_0-rmse:0.05988
# [425]	validation_0-rmse:0.05988
# [426]	validation_0-rmse:0.05988
# [427]	validation_0-rmse:0.05988
# [428]	validation_0-rmse:0.05988
# [429]	validation_0-rmse:0.05988
# [430]	validation_0-rmse:0.05988
# [431]	validation_0-rmse:0.05988
# Fold 3 RMSLE: 0.0599
# Training time: 49.2 sec
#
# Fold 4
# [0]	validation_0-rmse:0.94449
# [1]	validation_0-rmse:0.92658
# [2]	validation_0-rmse:0.90894
# [3]	validation_0-rmse:0.89160
# [4]	validation_0-rmse:0.87455
# [5]	validation_0-rmse:0.85778
# [6]	validation_0-rmse:0.84131
# [7]	validation_0-rmse:0.82512
# [8]	validation_0-rmse:0.80919
# [9]	validation_0-rmse:0.79354
# [10]	validation_0-rmse:0.77817
# [11]	validation_0-rmse:0.76306
# [12]	validation_0-rmse:0.74822
# [13]	validation_0-rmse:0.73362
# [14]	validation_0-rmse:0.71929
# [15]	validation_0-rmse:0.70521
# [16]	validation_0-rmse:0.69140
# [17]	validation_0-rmse:0.67785
# [18]	validation_0-rmse:0.66454
# [19]	validation_0-rmse:0.65149
# [20]	validation_0-rmse:0.63868
# [21]	validation_0-rmse:0.62612
# [22]	validation_0-rmse:0.61381
# [23]	validation_0-rmse:0.60174
# [24]	validation_0-rmse:0.58990
# [25]	validation_0-rmse:0.57830
# [26]	validation_0-rmse:0.56692
# [27]	validation_0-rmse:0.55577
# [28]	validation_0-rmse:0.54486
# [29]	validation_0-rmse:0.53415
# [30]	validation_0-rmse:0.52366
# [31]	validation_0-rmse:0.51338
# [32]	validation_0-rmse:0.50330
# [33]	validation_0-rmse:0.49344
# [34]	validation_0-rmse:0.48376
# [35]	validation_0-rmse:0.47429
# [36]	validation_0-rmse:0.46501
# [37]	validation_0-rmse:0.45591
# [38]	validation_0-rmse:0.44700
# [39]	validation_0-rmse:0.43827
# [40]	validation_0-rmse:0.42971
# [41]	validation_0-rmse:0.42133
# [42]	validation_0-rmse:0.41313
# [43]	validation_0-rmse:0.40508
# [44]	validation_0-rmse:0.39721
# [45]	validation_0-rmse:0.38949
# [46]	validation_0-rmse:0.38193
# [47]	validation_0-rmse:0.37452
# [129]	validation_0-rmse:0.09363
# [130]	validation_0-rmse:0.09255
# [131]	validation_0-rmse:0.09151
# [132]	validation_0-rmse:0.09049
# [133]	validation_0-rmse:0.08951
# [134]	validation_0-rmse:0.08855
# [135]	validation_0-rmse:0.08762
# [136]	validation_0-rmse:0.08672
# [137]	validation_0-rmse:0.08584
# [138]	validation_0-rmse:0.08499
# [139]	validation_0-rmse:0.08416
# [140]	validation_0-rmse:0.08336
# [141]	validation_0-rmse:0.08258
# [142]	validation_0-rmse:0.08183
# [143]	validation_0-rmse:0.08110
# [144]	validation_0-rmse:0.08039
# [145]	validation_0-rmse:0.07970
# [146]	validation_0-rmse:0.07903
# [147]	validation_0-rmse:0.07839
# [148]	validation_0-rmse:0.07776
# [149]	validation_0-rmse:0.07715
# [150]	validation_0-rmse:0.07657
# [151]	validation_0-rmse:0.07600
# [152]	validation_0-rmse:0.07544
# [153]	validation_0-rmse:0.07492
# [154]	validation_0-rmse:0.07440
# [155]	validation_0-rmse:0.07390
# [156]	validation_0-rmse:0.07342
# [157]	validation_0-rmse:0.07296
# [158]	validation_0-rmse:0.07251
# [159]	validation_0-rmse:0.07207
# [160]	validation_0-rmse:0.07165
# [161]	validation_0-rmse:0.07125
# [162]	validation_0-rmse:0.07085
# [163]	validation_0-rmse:0.07048
# [164]	validation_0-rmse:0.07011
# [165]	validation_0-rmse:0.06975
# [166]	validation_0-rmse:0.06941
# [167]	validation_0-rmse:0.06908
# [168]	validation_0-rmse:0.06876
# [169]	validation_0-rmse:0.06846
# [170]	validation_0-rmse:0.06816
# [171]	validation_0-rmse:0.06787
# [172]	validation_0-rmse:0.06760
# [173]	validation_0-rmse:0.06733
# [174]	validation_0-rmse:0.06707
# [175]	validation_0-rmse:0.06682
# [176]	validation_0-rmse:0.06658
# [177]	validation_0-rmse:0.06635
# [178]	validation_0-rmse:0.06613
# [179]	validation_0-rmse:0.06592
# [180]	validation_0-rmse:0.06571
# [181]	validation_0-rmse:0.06551
# [182]	validation_0-rmse:0.06532
# [183]	validation_0-rmse:0.06514
# [184]	validation_0-rmse:0.06496
# [185]	validation_0-rmse:0.06479
# [186]	validation_0-rmse:0.06462
# [187]	validation_0-rmse:0.06446
# [188]	validation_0-rmse:0.06430
# [189]	validation_0-rmse:0.06416
# [190]	validation_0-rmse:0.06401
# [191]	validation_0-rmse:0.06387
# [192]	validation_0-rmse:0.06374
# [193]	validation_0-rmse:0.06362
# [194]	validation_0-rmse:0.06350
# [195]	validation_0-rmse:0.06337
# [196]	validation_0-rmse:0.06326
# [197]	validation_0-rmse:0.06315
# [198]	validation_0-rmse:0.06304
# [199]	validation_0-rmse:0.06294
# [200]	validation_0-rmse:0.06284
# [201]	validation_0-rmse:0.06275
# [202]	validation_0-rmse:0.06266
# [203]	validation_0-rmse:0.06257
# [204]	validation_0-rmse:0.06248
# [205]	validation_0-rmse:0.06240
# [206]	validation_0-rmse:0.06232
# [207]	validation_0-rmse:0.06224
# [208]	validation_0-rmse:0.06217
# [209]	validation_0-rmse:0.06210
# [210]	validation_0-rmse:0.06203
# [211]	validation_0-rmse:0.06197
# [212]	validation_0-rmse:0.06191
# [213]	validation_0-rmse:0.06185
# [214]	validation_0-rmse:0.06179
# [215]	validation_0-rmse:0.06173
# [216]	validation_0-rmse:0.06168
# [217]	validation_0-rmse:0.06163
# [218]	validation_0-rmse:0.06158
# [219]	validation_0-rmse:0.06153
# [220]	validation_0-rmse:0.06148
# [221]	validation_0-rmse:0.06144
# [222]	validation_0-rmse:0.06139
# [223]	validation_0-rmse:0.06136
# [224]	validation_0-rmse:0.06132
# [225]	validation_0-rmse:0.06128
# [226]	validation_0-rmse:0.06125
# [227]	validation_0-rmse:0.06121
# [228]	validation_0-rmse:0.06117
# [229]	validation_0-rmse:0.06114
# [230]	validation_0-rmse:0.06111
# [231]	validation_0-rmse:0.06108
# [232]	validation_0-rmse:0.06105
# [233]	validation_0-rmse:0.06102
# [234]	validation_0-rmse:0.06099
# [235]	validation_0-rmse:0.06097
# [236]	validation_0-rmse:0.06094
# [237]	validation_0-rmse:0.06092
# [238]	validation_0-rmse:0.06089
# [239]	validation_0-rmse:0.06087
# [240]	validation_0-rmse:0.06085
# [241]	validation_0-rmse:0.06083
# [242]	validation_0-rmse:0.06081
# [243]	validation_0-rmse:0.06079
# [244]	validation_0-rmse:0.06077
# [245]	validation_0-rmse:0.06075
# [246]	validation_0-rmse:0.06073
# [247]	validation_0-rmse:0.06072
# [248]	validation_0-rmse:0.06070
# [249]	validation_0-rmse:0.06069
# [250]	validation_0-rmse:0.06067
# [251]	validation_0-rmse:0.06065
# [252]	validation_0-rmse:0.06064
# [253]	validation_0-rmse:0.06063
# [254]	validation_0-rmse:0.06061
# [255]	validation_0-rmse:0.06060
# [256]	validation_0-rmse:0.06059
# [257]	validation_0-rmse:0.06058
# [258]	validation_0-rmse:0.06056
# [259]	validation_0-rmse:0.06055
# [260]	validation_0-rmse:0.06054
# [261]	validation_0-rmse:0.06053
# [262]	validation_0-rmse:0.06052
# [263]	validation_0-rmse:0.06052
# [264]	validation_0-rmse:0.06051
# [265]	validation_0-rmse:0.06050
# [266]	validation_0-rmse:0.06049
# [267]	validation_0-rmse:0.06048
# [268]	validation_0-rmse:0.06047
# [269]	validation_0-rmse:0.06046
# [270]	validation_0-rmse:0.06046
# [271]	validation_0-rmse:0.06045
# [272]	validation_0-rmse:0.06044
# [273]	validation_0-rmse:0.06044
# [274]	validation_0-rmse:0.06043
# [275]	validation_0-rmse:0.06042
# [276]	validation_0-rmse:0.06042
# [277]	validation_0-rmse:0.06041
# [278]	validation_0-rmse:0.06041
# [279]	validation_0-rmse:0.06040
# [280]	validation_0-rmse:0.06040
# [281]	validation_0-rmse:0.06039
# [282]	validation_0-rmse:0.06039
# [283]	validation_0-rmse:0.06038
# [284]	validation_0-rmse:0.06038
# [285]	validation_0-rmse:0.06037
# [286]	validation_0-rmse:0.06037
# [287]	validation_0-rmse:0.06037
# [288]	validation_0-rmse:0.06036
# [289]	validation_0-rmse:0.06036
# [290]	validation_0-rmse:0.06036
# [291]	validation_0-rmse:0.06035
# [292]	validation_0-rmse:0.06035
# [293]	validation_0-rmse:0.06035
# [294]	validation_0-rmse:0.06034
# [295]	validation_0-rmse:0.06034
# [296]	validation_0-rmse:0.06034
# [297]	validation_0-rmse:0.06034
# [298]	validation_0-rmse:0.06033
# [299]	validation_0-rmse:0.06033
# [300]	validation_0-rmse:0.06033
# [301]	validation_0-rmse:0.06032
# [302]	validation_0-rmse:0.06032
# [303]	validation_0-rmse:0.06032
# [304]	validation_0-rmse:0.06031
# [305]	validation_0-rmse:0.06031
# [306]	validation_0-rmse:0.06031
# [307]	validation_0-rmse:0.06031
# [308]	validation_0-rmse:0.06030
# [309]	validation_0-rmse:0.06030
# [310]	validation_0-rmse:0.06030
# [311]	validation_0-rmse:0.06030
# [312]	validation_0-rmse:0.06030
# [313]	validation_0-rmse:0.06029
# [314]	validation_0-rmse:0.06029
# [315]	validation_0-rmse:0.06029
# [316]	validation_0-rmse:0.06029
# [317]	validation_0-rmse:0.06029
# [318]	validation_0-rmse:0.06029
# [319]	validation_0-rmse:0.06028
# [320]	validation_0-rmse:0.06028
# [321]	validation_0-rmse:0.06028
# [322]	validation_0-rmse:0.06028
# [323]	validation_0-rmse:0.06028
# [324]	validation_0-rmse:0.06028
# [325]	validation_0-rmse:0.06028
# [326]	validation_0-rmse:0.06028
# [327]	validation_0-rmse:0.06027
# [328]	validation_0-rmse:0.06027
# [329]	validation_0-rmse:0.06027
# [330]	validation_0-rmse:0.06027
# [331]	validation_0-rmse:0.06027
# [332]	validation_0-rmse:0.06027
# [333]	validation_0-rmse:0.06027
# [334]	validation_0-rmse:0.06027
# [335]	validation_0-rmse:0.06027
# [336]	validation_0-rmse:0.06027
# [337]	validation_0-rmse:0.06027
# [338]	validation_0-rmse:0.06027
# [339]	validation_0-rmse:0.06027
# [340]	validation_0-rmse:0.06027
# [341]	validation_0-rmse:0.06026
# [342]	validation_0-rmse:0.06026
# [343]	validation_0-rmse:0.06026
# [344]	validation_0-rmse:0.06026
# [345]	validation_0-rmse:0.06026
# [346]	validation_0-rmse:0.06026
# [347]	validation_0-rmse:0.06026
# [348]	validation_0-rmse:0.06026
# [349]	validation_0-rmse:0.06026
# [350]	validation_0-rmse:0.06026
# [351]	validation_0-rmse:0.06026
# [352]	validation_0-rmse:0.06026
# [353]	validation_0-rmse:0.06026
# [354]	validation_0-rmse:0.06026
# [355]	validation_0-rmse:0.06026
# [356]	validation_0-rmse:0.06026
# [357]	validation_0-rmse:0.06026
# [358]	validation_0-rmse:0.06026
# [359]	validation_0-rmse:0.06026
# [360]	validation_0-rmse:0.06026
# [361]	validation_0-rmse:0.06026
# [362]	validation_0-rmse:0.06026
# [363]	validation_0-rmse:0.06026
# [364]	validation_0-rmse:0.06026
# [365]	validation_0-rmse:0.06026
# [366]	validation_0-rmse:0.06026
# [367]	validation_0-rmse:0.06026
# [368]	validation_0-rmse:0.06026
# [369]	validation_0-rmse:0.06026
# [370]	validation_0-rmse:0.06026
# [371]	validation_0-rmse:0.06026
# [372]	validation_0-rmse:0.06026
# [373]	validation_0-rmse:0.06026
# [374]	validation_0-rmse:0.06026
# [375]	validation_0-rmse:0.06026
# [376]	validation_0-rmse:0.06026
# [377]	validation_0-rmse:0.06026
# [378]	validation_0-rmse:0.06026
# [379]	validation_0-rmse:0.06026
# [380]	validation_0-rmse:0.06026
# [381]	validation_0-rmse:0.06026
# [382]	validation_0-rmse:0.06026
# [383]	validation_0-rmse:0.06026
# [384]	validation_0-rmse:0.06026
# [385]	validation_0-rmse:0.06026
# [386]	validation_0-rmse:0.06026
# [387]	validation_0-rmse:0.06026
# [388]	validation_0-rmse:0.06026
# [389]	validation_0-rmse:0.06026
# [390]	validation_0-rmse:0.06026
# [391]	validation_0-rmse:0.06026
# [392]	validation_0-rmse:0.06026
# [393]	validation_0-rmse:0.06026
# [394]	validation_0-rmse:0.06026
# [395]	validation_0-rmse:0.06026
# [396]	validation_0-rmse:0.06026
# [397]	validation_0-rmse:0.06026
# [398]	validation_0-rmse:0.06026
# [399]	validation_0-rmse:0.06026
# [400]	validation_0-rmse:0.06026
# [401]	validation_0-rmse:0.06026
# [402]	validation_0-rmse:0.06026
# [403]	validation_0-rmse:0.06026
# [404]	validation_0-rmse:0.06026
# [405]	validation_0-rmse:0.06026
# [406]	validation_0-rmse:0.06026
# [407]	validation_0-rmse:0.06026
# [408]	validation_0-rmse:0.06026
# [409]	validation_0-rmse:0.06026
# [410]	validation_0-rmse:0.06026
# [411]	validation_0-rmse:0.06026
# [412]	validation_0-rmse:0.06026
# [413]	validation_0-rmse:0.06026
# [414]	validation_0-rmse:0.06026
# [415]	validation_0-rmse:0.06026
# [416]	validation_0-rmse:0.06026
# [417]	validation_0-rmse:0.06026
# [418]	validation_0-rmse:0.06026
# [419]	validation_0-rmse:0.06026
# [420]	validation_0-rmse:0.06026
# [421]	validation_0-rmse:0.06026
# [422]	validation_0-rmse:0.06026
# [423]	validation_0-rmse:0.06026
# [424]	validation_0-rmse:0.06026
# [425]	validation_0-rmse:0.06026
# [426]	validation_0-rmse:0.06026
# [427]	validation_0-rmse:0.06026
# [428]	validation_0-rmse:0.06026
# [429]	validation_0-rmse:0.06026
# [430]	validation_0-rmse:0.06026
# [431]	validation_0-rmse:0.06026
# [432]	validation_0-rmse:0.06026
# [433]	validation_0-rmse:0.06026
# [434]	validation_0-rmse:0.06026
# [435]	validation_0-rmse:0.06026
# Fold 4 RMSLE: 0.0603
# Training time: 49.9 sec
#
# === Training LightGBM ===
#
# Fold 1
# Fold 1 RMSLE: 0.0610
# Training time: 27.5 sec
#
# Fold 2
# Fold 2 RMSLE: 0.0606
# Training time: 27.5 sec
#
# Fold 3
# Fold 3 RMSLE: 0.0609
# Training time: 22.8 sec
#
# Fold 4
# Fold 4 RMSLE: 0.0608
# Training time: 22.5 sec
#
# === Model Comparison ===
# CatBoostRegressor - Mean RMSLE: 0.0601 ± 0.0001
# XGBoost - Mean RMSLE: 0.0600 ± 0.0002
# LightGBM - Mean RMSLE: 0.0608 ± 0.0002

# %%
from scipy.optimize import minimize
from sklearn.metrics import mean_squared_log_error

#oof予測・テスト予測・正解データを対数変換から戻す
oof_preds = {name: np.expm1(results[name]['oof']) for name in results}
test_preds = {name: np.expm1(results[name]['pred']) for name in results}
y_true = np.expm1(y)

#モデル名のリストを抽出
model_names = list(oof_preds.keys())

#最適化の目的関数(RSMLEを最小化)
def rmsle_loss(weights):
    #各モデルの重み付き平均で予測値をブレンド
    blended = sum(w * oof_preds[name] for w, name in zip(weights, model_names))
    #RSMLEを計算
    loss = np.sqrt(mean_squared_log_error(y_true, blended))
    print(f"weights: {weights}, RMSLE: {loss:.6f}")
    return loss.item()

#初期の重みは等分
initial_weights = [1 / len(model_names)] * len(model_names)
#重みの合計を1に制約
constraints = ({'type': 'eq', 'fun': lambda w: 1 - sum(w)})
#各重みは0~1の範囲に制限
bounds = [(0, 1)] * len(model_names)

#最適化実行(SLSQP法で連続最適化)
res = minimize(
    rmsle_loss, #最小化したい関数
    initial_weights, #初期値
    method='SLSQP', #最適化手法(連続制約付き最適化)
    bounds=bounds, #各重みの範囲
    constraints=constraints) #重みの合計が１である制約

#最適化された重みを取得
best_weights = res.x

# res.fun       # 最小化されたRMSLE
# res.success   # 最適化が成功したか（True/False）
# res.message   # 結果に関するメッセージ（失敗時に特に重要）

#重みの出力
print(f"\n✅ Optimized Weights:")
print(f"CatBoost = {best_weights[0]:.4f}")
print(f"XGBoost  = {best_weights[1]:.4f}")
print(f"LightGBM = {best_weights[2]:.4f}")

#最適重みによるテストデータの予測
blended_preds = sum(w * test_preds[name] for w, name in zip(best_weights, model_names))
#予測を適切な範囲(1~314)にクリップ
blended_preds = np.clip(blended_preds, 1, 314)

submission = pd.read_csv("playground-series-s5e5/sample_submission.csv")

submission['Calories'] = blended_preds
submission.to_csv('submission.csv', index=False)

print("\nSubmission Head:")
print(submission.head())

print(f"\nPredict Mean: {blended_preds.mean():.2f}")
print(f"Predict Median: {np.median(blended_preds):.2f}")
# Out:
# weights: [0.33333333 0.33333333 0.33333333], RMSLE: 0.059538
# weights: [0.33333335 0.33333333 0.33333333], RMSLE: 0.059538
# weights: [0.33333333 0.33333335 0.33333333], RMSLE: 0.059538
# weights: [0.33333333 0.33333333 0.33333335], RMSLE: 0.059538
#
# ✅ Optimized Weights:
# CatBoost = 0.3333
# XGBoost  = 0.3333
# LightGBM = 0.3333
#
# Submission Head:
#        id    Calories
# 0  750000   27.332461
# 1  750001  107.594434
# 2  750002   87.242586
# 3  750003  125.389014
# 4  750004   75.814062
#
# Predict Mean: 88.16
# Predict Median: 76.40

# %%
print(res)
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.05953801030803326
#        x: [ 3.333e-01  3.333e-01  3.333e-01]
#      nit: 1
#      jac: [ 7.554e-04  4.907e-04  1.255e-03]
#     nfev: 4
#     njev: 1

# %%
for name in oof_preds:
    print(f"{name}: mean={oof_preds[name].mean():.4f}, std={oof_preds[name].std():.4f}")
# Out:
# CatBoostRegressor: mean=88.2187, std=62.2950
# XGBoost: mean=88.1876, std=62.2402
# LightGBM: mean=88.1995, std=62.2547
